# %% [markdown]
# Nama : R.Muhammad Azmi Herdi Shofiyullah
#
# NIM : 2041720079
#
# Kelas / Absen : TI-3A / 21

# %% [markdown]
# ## Tugas
#
# 1. Menggunakan data (WBC) dan alogirtma yang sama (DT) pada jobsheet js11_02, silahkan implemnetasikan ulang teknik *exhausive search* dengan menggunakan ***random search***. Scikit-learn sudah menyediakan fungsi ini.
#
# 2. Menggunakan data yang sama, lakukan tunning dengan menggunakan algoritma SVM. Hyperparamter yang akan ditunning adalah,
#     - kernel (linier, polinomial, rbf)
#     - degree (akan berdampak jika polinomial)
#     - koefisien C (regularization)

# %% [markdown]
# ## TUGAS 1

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/wbc.csv')

# slice kolom terakhir --> Unnamed column
df = df.iloc[:,:-1]

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X = df.iloc[:, 2:]
y = df['diagnosis']

X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import RepeatedKFold

cv = RepeatedKFold(n_splits=4, n_repeats=3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt = DecisionTreeClassifier()

params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': list(range(5,11))
}

grid = GridSearchCV(dt, param_grid=params, cv=cv)

# %timeit grid.fit(X, y)

score = grid.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {grid.best_params_}')
# Out:
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\tree\_classes.py", line 898, in fit
#     super().fit(
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\tree\_classes.py", line 347, in fit
#     criterion = CRITERIA_CLF[self.criterion](self.n_outputs_,
# KeyError: 'log_loss'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV

clf = RandomizedSearchCV(dt, param_distributions=params, cv=cv)
# %timeit grid.fit(X, y)
search = clf.fit(X, y)

nilai = clf.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {search.best_params_}')
# Out:
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\tree\_classes.py", line 898, in fit
#     super().fit(
#   File "d:\Data\Anaconda\lib\site-packages\sklearn\tree\_classes.py", line 347, in fit
#     criterion = CRITERIA_CLF[self.criterion](self.n_outputs_,
# KeyError: 'log_loss'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %% [markdown]
# ## TUGAS 2

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from sklearn import svm

svc = svm.SVC()
params = {
    'kernel': ['rbf', 'linear', 'poly'],
    'C': [3],
    'degree': [1]
}

random = RandomizedSearchCV(svc, param_distributions=params, cv=cv, n_jobs=-1, )
# %timeit random.fit(X, y)

score = random.score(X,y)

print(f'Hasil evaluasi Random Search: {score}')
print(f'Konfigurasi hyperparameter Random Search: {random.best_params_}')
# Out:
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# d:\Data\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ...

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'kernel': ['rbf', 'linear', 'poly'],
    'C': [3],
    'degree': [1]
}

grid = GridSearchCV(svc, param_grid=params, cv=cv, n_jobs=-1)

# %timeit grid.fit(X, y)
score = grid.score(X,y)

print(f'Hasil evaluasi Grid Search: {score}')
print(f'Konfigurasi hyperparameter Grid Search: {grid.best_params_}')
# Out:
# 11.9 s ± 226 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Hasil evaluasi Grid Search: 0.9630931458699473
# Konfigurasi hyperparameter Grid Search: {'C': 3, 'degree': 1, 'kernel': 'linear'}
